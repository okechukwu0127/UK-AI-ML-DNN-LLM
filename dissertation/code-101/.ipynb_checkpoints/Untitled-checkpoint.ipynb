# %%
import tensorflow as tf
print(tf.__version__)

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.20.0
# Uninstalling tensorflow-2.20.0:
#   Would remove:
#     /opt/anaconda3/lib/python3.13/site-packages/tensorflow-2.20.0.dist-info/*
#     /opt/anaconda3/lib/python3.13/site-packages/tensorflow/*
# Proceed (Y/n)?
