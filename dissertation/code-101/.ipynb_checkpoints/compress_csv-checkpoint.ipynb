# %%
import pandas as pd

# Load original file
df = pd.read_csv("rbsqli_dataset_1k.csv")


#frac=0.10   # ~20 MB
#frac=0.25   # ~50 MB

# Keep first 25% of rows (adjust as needed)
smaller_df = df.sample(frac=0.02, random_state=42)

# Save smaller file
smaller_df.to_csv("rbsqli_dataset_small.csv", index=False)
# Out:
# /opt/anaconda3/lib/python3.13/site-packages/pandas/core/computation/expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
