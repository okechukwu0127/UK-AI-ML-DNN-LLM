# %% [markdown]
#  - This code implements a Naive Bayes classification model to predict which drug a person might be prescribed based on their medical attributes.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # MATLAB-like way of plotting
# sklearn package for machine learning in python:
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import make_classification
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('drug_data.csv')
print(df.head(),'\n')
print(df.info(), '\n')
# Out:
#    Age Sex      BP Cholesterol  Na_to_K   Drug
# 0   23   F    HIGH        HIGH   25.355  DrugY
# 1   47   M     LOW        HIGH   13.093  drugC
# 2   47   M     LOW        HIGH   10.114  drugC
# 3   28   F  NORMAL        HIGH    7.798  drugX
# 4   61   F     LOW        HIGH   18.043  DrugY
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na_to_K      200 non-null    float64
#  5   Drug         200 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 9.5+ KB
# None

# %%
label_list = ['Sex', 'BP', 'Cholesterol', 'Drug']

for l in label_list:
    df[l] = LabelEncoder().fit_transform(df[l])

# %% [markdown]
#  - Converts categorical string columns like "Sex" or "Cholesterol" into numeric values (required for ML models).
# ##### For example:
#
#  - Sex: Male → 1, Female → 0
#  - Drug: DrugA → 0, DrugB → 1, etc.

# %%
print(df.head(),'\n')
# Out:
#    Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0   23    0   0            0   25.355     0
# 1   47    1   1            0   13.093     3
# 2   47    1   1            0   10.114     3
# 3   28    0   2            0    7.798     4
# 4   61    0   1            0   18.043     0

# %%
X = df.iloc[:,:-1].values # all features (Age, Sex, BP, etc.)
y = df.iloc[:,-1].values  # target variable (Drug)

# %%
# split the data into training and test sets:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 1/3, random_state=2)

# %%
#Initializes and trains a Gaussian Naive Bayes classifier using the training data.
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# output the accuracy score
print('Our Accuracy is %.2f' % logre.score(X_test, y_test))

# output the number of mislabeled points
print('Number of mislabeled points out of a total %d points : %d'
% (X_test.shape[0], (y_test != logre.predict(X_test)).sum()))
# Out:
# Our Accuracy is 0.55
# Number of mislabeled points out of a total 67 points : 30

# %%
y_pred = gnb.predict([[20,0,2,0,7]])
print('Predict a value:', y_pred)
# Out:
# Predict a value: [4]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# Now split the scaled data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=1/3, random_state=2)

# %% [markdown]
# #### Bonus: Use a Different Solver (Optional)
#
# You can also try a different optimization algorithm:
#  -  But this is usually unnecessary unless you're doing large-scale or sparse data modeling.

# %%
logre = LogisticRegression(solver='saga', max_iter=1000)
logre.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000, solver='saga')

# %%
# accuracy score
print('Number of mislabeled points out of a total of %d points: %d'
% (X_test.shape[0], (y_test != gnb.predict(X_test)).sum()))

# number of mislabeled points
print('Our accuracy is %.2f:' % gnb.score(X_test, y_test))
# Out:
# Number of mislabeled points out of a total of 67 points: 29
# Our accuracy is 0.57:
