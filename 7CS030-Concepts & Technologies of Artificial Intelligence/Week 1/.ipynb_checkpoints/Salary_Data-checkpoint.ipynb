# %% [markdown]
# ### Summary of code
# - This script demonstrates a real-world linear regression model using actual data from a CSV file named salary_data.csv.
# - The goal is to predict a person's salary based on their years of experience.

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # MATLAB-like way of plotting

# sklearn package for machine learning in python:
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('salary_data.csv') # read data (make sure .csv in folder)
print(df.head()) # print first 5 rows of data
print(df.tail()) # print last 5 rows of data

print(df.describe()) # print mean, standard deviation, max, min, etc.
print(df.info()) # prints info about a DataFrame, dtype, non-null values, etc.
print(df.corr(),'\n') # print correlation coefficient for data
X = df.iloc[:, [0]].values # inputs YearsExperience
y = df.iloc[:, 1].values # outputs Salary
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0
#     YearsExperience    Salary
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
# ...

# %% [markdown]
# ### visualise initial data set

# %%
# visualise initial data set
fig1, ax1 = plt.subplots()
ax1.scatter(X, y, color = 'blue')
fig1.tight_layout()

# %%
# split the data into training and test sets:
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 1/3,random_state = 0)
# fit the linear least-squares regression line to the training data:
regr = LinearRegression()
regr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### visualise training set results

# %%
# visualise training set results
fig2, ax2 = plt.subplots()
ax2.scatter(X_train, y_train, color = 'red')
ax2.plot(X_train, regr.predict(X_train), color = 'blue')
fig2.tight_layout()

# %% [markdown]
# ### visualise test set results

# %%
# visualise test set results
fig3, ax3 = plt.subplots()
ax3.scatter(X_test, y_test, color = 'red')
ax3.plot(X_test, regr.predict(X_test), color = 'blue')
ax3.set_title('Salary vs Experience (Test set)')
ax3.set_xlabel('Years of Experience')
ax3.set_ylabel('Salary')
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ### Single Prediction
# Predicts salary for someone with 6 years of experience
#
#   - This works perfectly because:
#     - You’re feeding in the independent variable (X) → Years of Experience
#     - The model is trained to predict the dependent variable (y) → Salary

# %%
print('Predict single value: ', regr.predict(np.array([[6]])))
# Out:
# Predict single value:  [82891.84690277]

# %%
# The coefficients
print('Coefficients: ', regr.coef_)

# The intercept
print('Intercept: ', regr.intercept_)



print('\n\n################### TEST MODEL #########################')
# The mean squared error
print('Mean squared error: %.8f'
% mean_squared_error(y_test, regr.predict(X_test)))

# The R^2 value:
print('Coefficient of determination: %.2f'
% r2_score(y_test, regr.predict(X_test)))




print('\n\n#################### TRAINED MONEL ########################')

# The mean squared error
print('Mean squared error: %.8f'
% mean_squared_error(y_train, regr.predict(X_train)))

# The R^2 value:
print('Coefficient of determination: %.2f'
% r2_score(y_train, regr.predict(X_train)))
# Out:
# Coefficients:  [9345.94244312]
# Intercept:  26816.19224403119
# Predict single value:  [82891.84690277]
#
#
# ################### TEST MODEL #########################
# Mean squared error: 21026037.32951130
# Coefficient of determination: 0.97
#
#
# #################### TRAINED MONEL ########################
# Mean squared error: 36852948.76438455
# Coefficient of determination: 0.94
